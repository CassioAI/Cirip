# %%
#Importing the used packages
#Numpy for arrays
import numpy as np
#PIL.Image for images
from PIL import Image
#Request and io.BytesIO for openning images from url
import requests
from io import BytesIO
#For showing the results
import matplotlib.pylab as plt
# %matplotlib inline

# %%
def img_grayscale(imageArray):
  imgArr= np.empty([1])
  for image in imageArray:
    pil_imgray = image.convert('LA')
    img = np.array(list(pil_imgray.getdata(band=0)), int)
    img.shape = (pil_imgray.size[1], pil_imgray.size[0])
    imgArr=np.append(imgArr,img)
  imgArr = np.delete(imgArr,0)
  imgArr.shape = (len(imageArray),pil_imgray.size[1], pil_imgray.size[0])
  return imgArr;
#The function is used to make the images to 1:1 ratio
def cropImage(image):
  #Taking out the image data (width,height)
  width, height = image.size
  #Deciding if the image is landscape or portrait
  if(width > height):
    #Landscape
    top     = 0
    left    = int((width - height)/2)
    bottom  = height
    right    = width - int((width - height)/2)
  else:
    #Portrait
    top     = int((height - width)/2)
    left    = 0
    bottom  = height-int((height - width)/2)
    right    = width

  return image.crop((left,top,right,bottom))
#Normalizing the inputted array images
def standard(array):
  #Calculating average on all the images
  ave = np.average(array)
  #Calculating standard distribution on all the images
  std = np.std(array)
  #Normalizing the inputted array
  new_array = (array-ave)/std
  #Returning normalized array, average, distribution
  return new_array,ave,std

# %%
URL=np.array(["https://farm7.staticflickr.com/7068/6957834490_696eb76979_o.jpg",
              "https://farm6.staticflickr.com/4126/5145819744_b4a7871064_o.jpg",
              "https://c4.staticflickr.com/3/2299/2536649553_2b4b4d8c0a_o.jpg",
              "https://i.stack.imgur.com/397vv.png"])

# %%
try:
    imageArray = [cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS)]
except IOError:
    print("Error, was unable to load images to imageArray")
    pass

# %%
normalizalt, nomalizaltatlag, normalizaltszoras =standard(img_grayscale(imageArray))

# %%
try:
    imageArray = [cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                 cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                 cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                 cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                 cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                 cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                 cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                 cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                 cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                 cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[2]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[3]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[0]).content))).resize((256,256),Image.ANTIALIAS),
                  cropImage(Image.open(BytesIO(requests.get(URL[1]).content))).resize((256,256),Image.ANTIALIAS)]
except IOError:
    print("Error, was unable to load images to imageArray")
    pass

# %%
#Visualization for the images
def image_mosaic(imagearray,size):
  #How many picture will be in one edge
  width=int(np.sqrt(len(imagearray)))
  #Initializing canvas
  canvas= np.ones((size*width,size*width*2,3));
  #Resizing images
  for i in range(len(imagearray)):
    imagearray[i]=imagearray[i].resize((size,size),Image.ANTIALIAS)
  #Making GrayImages
  grayimage=img_grayscale(imagearray)
  #Writing the RGB images to the canvas right side
  for i in range(width):
    for j in range(width):
      canvas[i*size:(i+1)*size,j*size:(j+1)*size,0::]=np.array(imagearray[i+width*j])
  #Writing grayscale images to the canvas left side
  for i in range(width):
    for j in range(width,2*width):
      canvas[i*size:(i+1)*size,j*size:(j+1)*size,0]=np.array(grayimage[i+width*(j-width)])
      canvas[i*size:(i+1)*size,j*size:(j+1)*size,1]=np.array(grayimage[i+width*(j-width)])
      canvas[i*size:(i+1)*size,j*size:(j+1)*size,2]=np.array(grayimage[i+width*(j-width)])
  #Returning the mosaic image
  return canvas.astype(np.uint8);
#RGB to grayscale converter
def img_grayscale(imageArray):
  imgArr= np.empty([1])
  for image in imageArray:
    pil_imgray = image.convert('LA')
    img = np.array(list(pil_imgray.getdata(band=0)), int)
    img.shape = (pil_imgray.size[1], pil_imgray.size[0])
    imgArr=np.append(imgArr,img)
  imgArr = np.delete(imgArr,0)
  imgArr.shape = (len(imageArray),pil_imgray.size[1], pil_imgray.size[0])
  return imgArr;

# %%
canva=image_mosaic(imageArray,64)
plt.grid(False)
plt.imshow(canva)

import scipy.misc
vizual=scipy.misc.toimage(canva, cmin=0.0, cmax=...)
vizual
# Out:
# (640, 1280, 3)
# <PIL.Image.Image image mode=RGB size=1280x640 at 0x7F4843E9C048>
